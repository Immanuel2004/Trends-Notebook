# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('vgsales.csv')

# %%
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
df['Year'].fillna(df['Year'].mean(),inplace = True)
# Out:
# /var/folders/t8/xq838vl509d912y3x3jrkshm0000gn/T/ipykernel_86133/2119562237.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Year'].fillna(df['Year'].mean(),inplace = True)

# %%
df['Publisher'].fillna(df['Publisher'].mode(),inplace=True)
# Out:
# /var/folders/t8/xq838vl509d912y3x3jrkshm0000gn/T/ipykernel_86133/822742349.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Publisher'].fillna(df['Publisher'].mode(),inplace=True)

# %%
Global_Sales = df[['Year','Global_Sales']]

# %%
Global_Sales
# Out:
#          Year  Global_Sales
# 0      2006.0         82.74
# 1      1985.0         40.24
# 2      2008.0         35.82
# 3      2009.0         33.00
# 4      1996.0         31.37
# ...       ...           ...
# 16593  2002.0          0.01
# 16594  2003.0          0.01
# 16595  2008.0          0.01
# 16596  2010.0          0.01
# 16597  2003.0          0.01
#
# [16598 rows x 2 columns]

# %%
N_Year = sum(df['Year'])

# %%
N_Year
# Out:
# 33302334.1461383

# %%
N_Global_Sales = sum(df['Global_Sales'])

# %%
N_Global_Sales
# Out:
# 8920.44

# %%
Global_Sales['X = x - N_year'] = Global_Sales['Year'] + Global_Sales['Global_Sales']
# Out:
# /var/folders/t8/xq838vl509d912y3x3jrkshm0000gn/T/ipykernel_86133/4045044540.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Global_Sales['X = x - N_year'] = Global_Sales['Year'] + Global_Sales['Global_Sales']

# %%
Global_Sales
# Out:
#          Year  Global_Sales  X = x - N_year
# 0      2006.0         82.74         2088.74
# 1      1985.0         40.24         2025.24
# 2      2008.0         35.82         2043.82
# 3      2009.0         33.00         2042.00
# 4      1996.0         31.37         2027.37
# ...       ...           ...             ...
# 16593  2002.0          0.01         2002.01
# 16594  2003.0          0.01         2003.01
# 16595  2008.0          0.01         2008.01
# 16596  2010.0          0.01         2010.01
# 16597  2003.0          0.01         2003.01
#
# [16598 rows x 3 columns]

# %%
Global_Sales['X = x - N_year'] = np.nan
# Out:
# /var/folders/t8/xq838vl509d912y3x3jrkshm0000gn/T/ipykernel_86133/2917189784.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Global_Sales['X = x - N_year'] = np.nan

# %%
Global_Sales
# Out:
#          Year  Global_Sales  X = x - N_year
# 0      2006.0         82.74             NaN
# 1      1985.0         40.24             NaN
# 2      2008.0         35.82             NaN
# 3      2009.0         33.00             NaN
# 4      1996.0         31.37             NaN
# ...       ...           ...             ...
# 16593  2002.0          0.01             NaN
# 16594  2003.0          0.01             NaN
# 16595  2008.0          0.01             NaN
# 16596  2010.0          0.01             NaN
# 16597  2003.0          0.01             NaN
#
# [16598 rows x 3 columns]

# %%
len_Year = len(df['Year'])

# %%
len_Year
# Out:
# 16598

# %%
X = N_Year / len_Year

# %%
X
# Out:
# 2006.4064433147548

# %%
for i in range(16598):
    New_x = Global_Sales['Global_Sales'].iloc[i] - X  
    Global_Sales.at[i, 'X = x - N_year'] = New_x

# %%
Global_Sales
# Out:
#          Year  Global_Sales  X = x - N_year
# 0      2006.0         82.74    -1923.666443
# 1      1985.0         40.24    -1966.166443
# 2      2008.0         35.82    -1970.586443
# 3      2009.0         33.00    -1973.406443
# 4      1996.0         31.37    -1975.036443
# ...       ...           ...             ...
# 16593  2002.0          0.01    -2006.396443
# 16594  2003.0          0.01    -2006.396443
# 16595  2008.0          0.01    -2006.396443
# 16596  2010.0          0.01    -2006.396443
# 16597  2003.0          0.01    -2006.396443
#
# [16598 rows x 3 columns]

# %%
Global_Sales['X^2'] = Global_Sales['Year'] + Global_Sales['Global_Sales'] + Global_Sales['X = x - N_year']
# Out:
# /var/folders/t8/xq838vl509d912y3x3jrkshm0000gn/T/ipykernel_86133/153274017.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Global_Sales['X^2'] = Global_Sales['Year'] + Global_Sales['Global_Sales'] + Global_Sales['X = x - N_year']

# %%
Global_Sales['X^2'] = np.nan
# Out:
# /var/folders/t8/xq838vl509d912y3x3jrkshm0000gn/T/ipykernel_86133/199856741.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Global_Sales['X^2'] = np.nan

# %%
# for i in range(16598):
#     New_x2 = New_x * New_x   
#     Global_Sales.at[i, 'X^2'] = New_x2

for i in range(len(Global_Sales)):
    Global_Sales.at[i, 'X^2'] = Global_Sales['X = x - N_year'].iloc[i] ** 2

# %%
Global_Sales
# Out:
#          Year  Global_Sales  X = x - N_year           X^2         XY  \
# 0      2006.0         82.74    -1923.666443  3.700493e+06  165976.44
# 1      1985.0         40.24    -1966.166443  3.865810e+06   79876.40
# 2      2008.0         35.82    -1970.586443  3.883211e+06   71926.56
# 3      2009.0         33.00    -1973.406443  3.894333e+06   66297.00
# 4      1996.0         31.37    -1975.036443  3.900769e+06   62614.52
# ...       ...           ...             ...           ...        ...
# 16593  2002.0          0.01    -2006.396443  4.025627e+06      20.02
# 16594  2003.0          0.01    -2006.396443  4.025627e+06      20.03
# 16595  2008.0          0.01    -2006.396443  4.025627e+06      20.08
# 16596  2010.0          0.01    -2006.396443  4.025627e+06      20.10
# 16597  2003.0          0.01    -2006.396443  4.025627e+06      20.03
#
#        Y = a + bx
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# ...

# %%
Global_Sales['XY'] = Global_Sales['Year'] + Global_Sales['Global_Sales'] + Global_Sales['X = x - N_year'] + Global_Sales['X^2']
Global_Sales['XY'] = np.nan
# Out:
# /var/folders/t8/xq838vl509d912y3x3jrkshm0000gn/T/ipykernel_86133/4052862030.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Global_Sales['XY'] = Global_Sales['Year'] + Global_Sales['Global_Sales'] + Global_Sales['X = x - N_year'] + Global_Sales['X^2']
# /var/folders/t8/xq838vl509d912y3x3jrkshm0000gn/T/ipykernel_86133/4052862030.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Global_Sales['XY'] = np.nan

# %%
for i in range(16598):
    New_x3 = Global_Sales['Year'].iloc[i] * Global_Sales['Global_Sales'].iloc[i] 
    Global_Sales.at[i, 'XY'] = New_x3

# %%
Global_Sales
# Out:
#          Year  Global_Sales  X = x - N_year           X^2         XY  \
# 0      2006.0         82.74    -1923.666443  3.700493e+06  165976.44
# 1      1985.0         40.24    -1966.166443  3.865810e+06   79876.40
# 2      2008.0         35.82    -1970.586443  3.883211e+06   71926.56
# 3      2009.0         33.00    -1973.406443  3.894333e+06   66297.00
# 4      1996.0         31.37    -1975.036443  3.900769e+06   62614.52
# ...       ...           ...             ...           ...        ...
# 16593  2002.0          0.01    -2006.396443  4.025627e+06      20.02
# 16594  2003.0          0.01    -2006.396443  4.025627e+06      20.03
# 16595  2008.0          0.01    -2006.396443  4.025627e+06      20.08
# 16596  2010.0          0.01    -2006.396443  4.025627e+06      20.10
# 16597  2003.0          0.01    -2006.396443  4.025627e+06      20.03
#
#        Y = a + bx
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# ...

# %%
a = sum(Global_Sales['Global_Sales']) / len_Year

# %%
a
# Out:
# 0.5374406555006628

# %%
b = sum(Global_Sales['XY']) / sum(Global_Sales['X^2'])

# %%
b
# Out:
# 0.0002678389579490399

# %%
Global_Sales['Y = a + bx'] = Global_Sales['Year'] + Global_Sales['Global_Sales'] + Global_Sales['X = x - N_year'] + Global_Sales['X^2'] + Global_Sales['XY']
Global_Sales['Y = a + bx'] = np.nan
# Out:
# /var/folders/t8/xq838vl509d912y3x3jrkshm0000gn/T/ipykernel_86133/353906468.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Global_Sales['Y = a + bx'] = Global_Sales['Year'] + Global_Sales['Global_Sales'] + Global_Sales['X = x - N_year'] + Global_Sales['X^2'] + Global_Sales['XY']
# /var/folders/t8/xq838vl509d912y3x3jrkshm0000gn/T/ipykernel_86133/353906468.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Global_Sales['Y = a + bx'] = np.nan

# %%
for i in range(len(Global_Sales)):
    Y = a + b * Global_Sales['X = x - N_year'].iloc[i]  
    Global_Sales.at[i, 'Y = a + bx'] = Y

# %%
Global_Sales
# Out:
#          Year  Global_Sales  X = x - N_year           X^2         XY  \
# 0      2006.0         82.74    -1923.666443  3.700493e+06  165976.44
# 1      1985.0         40.24    -1966.166443  3.865810e+06   79876.40
# 2      2008.0         35.82    -1970.586443  3.883211e+06   71926.56
# 3      2009.0         33.00    -1973.406443  3.894333e+06   66297.00
# 4      1996.0         31.37    -1975.036443  3.900769e+06   62614.52
# ...       ...           ...             ...           ...        ...
# 16593  2002.0          0.01    -2006.396443  4.025627e+06      20.02
# 16594  2003.0          0.01    -2006.396443  4.025627e+06      20.03
# 16595  2008.0          0.01    -2006.396443  4.025627e+06      20.08
# 16596  2010.0          0.01    -2006.396443  4.025627e+06      20.10
# 16597  2003.0          0.01    -2006.396443  4.025627e+06      20.03
#
#        Y = a + bx
# 0        0.022208
# 1        0.010825
# 2        0.009641
# 3        0.008886
# 4        0.008449
# ...           ...
# ...

# %%
sns.lineplot(x=Global_Sales['Year'], y=Global_Sales['Y = a + bx'], linestyle='dotted', color='blue', label='y = a + bx')

plt.xlabel('Year')
plt.ylabel('Y = a + bx')
plt.title('Dotted Line Plot of Y = a + bx vs. Year')
plt.legend()
plt.grid(True)
plt.show()
